# %%
import pandas as pd

# %%
df= pd.read_csv("data/batches.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   batch_id          25 non-null     int64
#  1   batch_name        25 non-null     str
#  2   academic_year_id  25 non-null     int64
#  3   course_id         25 non-null     int64
#  4   teacher_id        25 non-null     int64
#  5   shift             25 non-null     str
#  6   start_time        25 non-null     str
#  7   end_time          25 non-null     str
#  8   room_no           25 non-null     int64
#  9   max_students      25 non-null     int64
#  10  status            25 non-null     str
# dtypes: int64(6), str(5)
# memory usage: 3.4 KB

# %%
df.drop('shift', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   batch_id          25 non-null     int64
#  1   batch_name        25 non-null     str
#  2   academic_year_id  25 non-null     int64
#  3   course_id         25 non-null     int64
#  4   teacher_id        25 non-null     int64
#  5   start_time        25 non-null     str
#  6   end_time          25 non-null     str
#  7   room_no           25 non-null     int64
#  8   max_students      25 non-null     int64
#  9   status            25 non-null     str
# dtypes: int64(6), str(4)
# memory usage: 3.0 KB

# %%
df.to_csv(r'D:\radius-academic-analytics\data\batches1.csv', index=False)
